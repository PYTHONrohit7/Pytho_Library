# %%
import pandas as pd

# %%
df=pd.read_csv("us_car_data.csv") #This is Electric Vehicle data from diff County

# %%
df.head()  #Print Head of datafrom
# Out:
#       County       City State  Postal Code  Model Year    Make    Model  \
# 0   Thurston   Tumwater    WA        98512        2019   TESLA  MODEL 3
# 1     Island    Clinton    WA        98236        2022  NISSAN     LEAF
# 2  Snohomish  Snohomish    WA        98290        2020   TESLA  MODEL 3
# 3       King    Seattle    WA        98134        2020   TESLA  MODEL 3
# 4  Snohomish    Edmonds    WA        98020        2013   TESLA  MODEL S
#
#          Electric Vehicle Type  \
# 0  Battery Electric Vehicle
# 1  Battery Electric Vehicle
# 2  Battery Electric Vehicle
# 3  Battery Electric Vehicle
# 4  Battery Electric Vehicle
#
#                                                 CAFV  Electric Range  \
# 0            Clean Alternative Fuel Vehicle Eligible             220
# 1  Eligibility unknown as battery range has not b...               0
# 2            Clean Alternative Fuel Vehicle Eligible             266
# 3            Clean Alternative Fuel Vehicle Eligible             322
# ...

# %%
df.dtypes #To show data types of Csv
# Out:
# County                    object
# City                      object
# State                     object
# Postal Code                int64
# Model Year                 int64
# Make                      object
# Model                     object
# Electric Vehicle Type     object
# CAFV                      object
# Electric Range             int64
# Base MSRP                  int64
# Legislative District       int64
# DOL Vehicle ID             int64
# Electric Utility          object
# 2020 Census Tract          int64
# Longitude                float64
# latitude                 float64
# dtype: object

# %%
df.describe() # To describe Mathamatical opration
# Out:
#          Postal Code     Model Year  Electric Range      Base MSRP  \
# count  134474.000000  134474.000000   134474.000000  134474.000000
# mean    98259.228520    2019.657250       74.730208    1451.396069
# std       303.069045       3.001443       98.776037    9691.900720
# min     98001.000000    1997.000000        0.000000       0.000000
# 25%     98052.000000    2018.000000        0.000000       0.000000
# 50%     98122.000000    2021.000000       21.000000       0.000000
# 75%     98370.000000    2022.000000      150.000000       0.000000
# max     99403.000000    2024.000000      337.000000  845000.000000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract      Longitude  \
# count         134474.000000    1.344740e+05       1.344740e+05  134474.000000
# mean              29.499911    2.063218e+08       5.303964e+10    -122.092668
# std               14.786294    8.590842e+07       1.617660e+07       1.006671
# ...

# %% [markdown]
# #### Club diff column in dataFrame

# %%
df[['County','Make','Model Year','Electric Range','Legislative District']]
# Out:
#            County     Make  Model Year  Electric Range  Legislative District
# 0        Thurston    TESLA        2019             220                    22
# 1          Island   NISSAN        2022               0                    10
# 2       Snohomish    TESLA        2020             266                    44
# 3            King    TESLA        2020             322                    11
# 4       Snohomish    TESLA        2013             208                    21
# ...           ...      ...         ...             ...                   ...
# 134469       King    TESLA        2020             330                    48
# 134470       King    TESLA        2021               0                    33
# 134471     Pierce    TESLA        2022               0                    26
# 134472      Grant  HYUNDAI        2023               0                    13
# 134473     Kitsap     FORD        2014              19                    26
#
# [134474 rows x 5 columns]

# %%
list[df.columns]  #list columns
# Out:
# list[Index(['County', 'City', 'State', 'Postal Code', 'Model Year', 'Make', 'Model',
#        'Electric Vehicle Type', 'CAFV', 'Electric Range', 'Base MSRP',
#        'Legislative District', 'DOL Vehicle ID', 'Electric Utility',
#        '2020 Census Tract', 'Longitude', 'latitude'],
#       dtype='object')]

# %% [markdown]
# ## How to save dataFrame

# %%
df.to_csv('data_ElectricV.csv',index=False)

# %% [markdown]
# #### Check data type in dataFrame

# %%
df.dtypes=='object'
# Out:
# County                    True
# City                      True
# State                     True
# Postal Code              False
# Model Year               False
# Make                      True
# Model                     True
# Electric Vehicle Type     True
# CAFV                      True
# Electric Range           False
# Base MSRP                False
# Legislative District     False
# DOL Vehicle ID           False
# Electric Utility          True
# 2020 Census Tract        False
# Longitude                False
# latitude                 False
# dtype: bool

# %%
df.dtypes[df.dtypes=='object']  #List of Object DataType
# Out:
# County                   object
# City                     object
# State                    object
# Make                     object
# Model                    object
# Electric Vehicle Type    object
# CAFV                     object
# Electric Utility         object
# dtype: object

# %% [markdown]
# #### To describe specific like object from index

# %%
df[df.dtypes[df.dtypes=='object'].index].describe()
# Out:
#         County     City   State    Make    Model        Electric Vehicle Type  \
# count   134474   134474  134474  134474   134474                       134474
# unique      39      454       1      36      125                            2
# top       King  Seattle      WA   TESLA  MODEL 3  Battery Electric Vehicle
# freq     70682    23408  134474   61650    25752                       103424
#
#                                            CAFV  \
# count                                    134474
# unique                                        3
# top     Clean Alternative Fuel Vehicle Eligible
# freq                                      61082
#
#                                      Electric Utility
# count                                          134474
# unique                                             75
# top     PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)
# freq                                            49285

# %%
df[df.dtypes[df.dtypes=='float'].index].describe()
# Out:
#            Longitude       latitude
# count  134474.000000  134474.000000
# mean     -122.092668      47.467715
# std         1.006671       0.615275
# min      -124.625140      45.583863
# 25%      -122.405565      47.357985
# 50%      -122.296385      47.613850
# 75%      -122.151665      47.715580
# max      -117.044370      48.996340

# %%
df[['County','City','Make']][3:10]   #To extract sab data-set from dataframe
# Out:
#       County        City    Make
# 3       King     Seattle   TESLA
# 4  Snohomish     Edmonds   TESLA
# 5     Chelan      Manson     BMW
# 6  Snohomish  Marysville   TESLA
# 7  Snohomish     Edmonds    AUDI
# 8   Thurston     Olympia  TOYOTA
# 9   Thurston       Lacey  NISSAN

# %%
df['Car_id']=df['Model']+'_'+df['Make']

# %%
df    #Make New column in data set
# Out:
#            County          City State  Postal Code  Model Year     Make  \
# 0        Thurston      Tumwater    WA        98512        2019    TESLA
# 1          Island       Clinton    WA        98236        2022   NISSAN
# 2       Snohomish     Snohomish    WA        98290        2020    TESLA
# 3            King       Seattle    WA        98134        2020    TESLA
# 4       Snohomish       Edmonds    WA        98020        2013    TESLA
# ...           ...           ...   ...          ...         ...      ...
# 134469       King  Yarrow Point    WA        98004        2020    TESLA
# 134470       King        Burien    WA        98168        2021    TESLA
# 134471     Pierce    Gig Harbor    WA        98335        2022    TESLA
# 134472      Grant       Ephrata    WA        98823        2023  HYUNDAI
# 134473     Kitsap  Port Orchard    WA        98366        2014     FORD
#
#           Model               Electric Vehicle Type  \
# ...

# %%
list[pd.Categorical(df['Model Year'])]      #List of Categorical data in data-set
# Out:
# list[[2019, 2022, 2020, 2020, 2013, ..., 2020, 2021, 2022, 2023, 2014]
# Length: 134474
# Categories (22, int64): [1997, 1998, 1999, 2000, ..., 2021, 2022, 2023, 2024]]

# %%
df['Make'].unique()
# Out:
# array(['TESLA', 'NISSAN', 'BMW', 'AUDI', 'TOYOTA', 'KIA', 'FIAT', 'FORD',
#        'CHEVROLET', 'HYUNDAI', 'VOLVO', 'VOLKSWAGEN', 'CHRYSLER', 'SMART',
#        'RIVIAN', 'SUBARU', 'JEEP', 'HONDA', 'LINCOLN', 'LUCID', 'PORSCHE',
#        'MITSUBISHI', 'POLESTAR', 'MERCEDES-BENZ', 'MINI', 'JAGUAR',
#        'CADILLAC', 'LEXUS', 'GENESIS', 'WHEEGO ELECTRIC CARS', 'FISKER',
#        'MAZDA', 'BENTLEY', 'TH!NK', 'LAND ROVER', 'AZURE DYNAMICS'],
#       dtype=object)

# %%
df['Model Year']<2020
# Out:
# 0          True
# 1         False
# 2         False
# 3         False
# 4          True
#           ...
# 134469    False
# 134470    False
# 134471    False
# 134472    False
# 134473     True
# Name: Model Year, Length: 134474, dtype: bool

# %%
df[df['Make']=='LAND ROVER']
# Out:
#            County           City State  Postal Code  Model Year        Make  \
# 13878        King      Sammamish    WA        98074        2020  LAND ROVER
# 15928        King        Seattle    WA        98133        2020  LAND ROVER
# 16549        King    Woodinville    WA        98072        2020  LAND ROVER
# 18778        King        Seattle    WA        98103        2020  LAND ROVER
# 19692        King       Issaquah    WA        98029        2023  LAND ROVER
# 20271        King       Bellevue    WA        98005        2020  LAND ROVER
# 21667        King        Seattle    WA        98122        2020  LAND ROVER
# 29729      Yakima         Yakima    WA        98908        2020  LAND ROVER
# 30437        King         Auburn    WA        98001        2021  LAND ROVER
# 35638      Skagit      Anacortes    WA        98221        2020  LAND ROVER
# 35778        King      Sammamish    WA        98075        2021  LAND ROVER
# ...

# %%
df[(df['Make']=='LAND ROVER') & (df['Model Year']>2020)]   #Apply AND || OR || NOT Equal opration b/w Column
# Out:
#           County           City State  Postal Code  Model Year        Make  \
# 19692       King       Issaquah    WA        98029        2023  LAND ROVER
# 30437       King         Auburn    WA        98001        2021  LAND ROVER
# 35778       King      Sammamish    WA        98075        2021  LAND ROVER
# 55858       King      Sammamish    WA        98074        2021  LAND ROVER
# 74812       King     Ravensdale    WA        98051        2021  LAND ROVER
# 76924       King      Carnation    WA        98014        2021  LAND ROVER
# 95750   San Juan  Friday Harbor    WA        98250        2023  LAND ROVER
# 101699      King        Seattle    WA        98121        2021  LAND ROVER
# 104437      King        Seattle    WA        98112        2023  LAND ROVER
# 113877    Pierce    Bonney Lake    WA        98391        2021  LAND ROVER
# 117378      King        Redmond    WA        98053        2023  LAND ROVER
# ...

# %%
df[df['Electric Range']==max(df['Electric Range'])]['Make']
# Out:
# 615       TESLA
# 3500      TESLA
# 5556      TESLA
# 8512      TESLA
# 10473     TESLA
#           ...
# 124583    TESLA
# 130335    TESLA
# 130699    TESLA
# 130872    TESLA
# 132270    TESLA
# Name: Make, Length: 76, dtype: object

# %% [markdown]
# ### Some Function like Loc/ ILoc in Data-Set

# %%
df.loc[2:8,['County','Make','Model']]
# Out:
#       County    Make        Model
# 2  Snohomish   TESLA      MODEL 3
# 3       King   TESLA      MODEL 3
# 4  Snohomish   TESLA      MODEL S
# 5     Chelan     BMW           I3
# 6  Snohomish   TESLA      MODEL 3
# 7  Snohomish    AUDI         Q5 E
# 8   Thurston  TOYOTA  PRIUS PRIME

# %%
df.iloc[2:8,[2,3,5]]
# Out:
#   State  Postal Code   Make
# 2    WA        98290  TESLA
# 3    WA        98134  TESLA
# 4    WA        98020  TESLA
# 5    WA        98831    BMW
# 6    WA        98271  TESLA
# 7    WA        98026   AUDI
